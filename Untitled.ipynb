# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import plot_confusion_matrix
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report,confusion_matrix
import numpy as np

# Read in data
X_train = np.genfromtxt("data/train_features.csv")
y_train = np.genfromtxt("data/train_labels.csv")
X_test = np.genfromtxt("data/test_features.csv")
y_test = np.genfromtxt("data/test_labels.csv")

# Fit a model
depth = 10
clf = RandomForestClassifier(max_depth=depth)
clf.fit(X_train,y_train)
acc = clf.score(X_test, y_test)

from lazypredict.Supervised import LazyClassifier
lazy_clf = LazyClassifier(verbose=0,ignore_warnings=True, custom_metric=None)
models, predictions = lazy_clf.fit(X_train, X_test, y_train, y_test)

print(models)
print(acc)
print(confusion_matrix(y_test, clf.predict(X_test)))
print(classification_report(y_test, clf.predict(X_test),digits=4))

with open("metrics.txt", 'w') as outfile:
        outfile.write(str(models) + "\n\n")
        outfile.write("Accuracy: " + str(acc) + "\n\n")
        outfile.write(str(confusion_matrix(y_test, clf.predict(X_test))) + "\n\n")
        outfile.write(str(classification_report(y_test, clf.predict(X_test),digits=4)) + "\n")   

# Plot it
disp = plot_confusion_matrix(clf, X_test, y_test, normalize='true',cmap=plt.cm.Blues)
plt.savefig('confusion_matrix.png')
# Out:
# 100%|██████████| 29/29 [00:01<00:00, 25.64it/s]
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# XGBClassifier                      0.91               0.91     0.91      0.91
# LGBMClassifier                     0.90               0.90     0.90      0.90
# RandomForestClassifier             0.88               0.88     0.88      0.88
# BaggingClassifier                  0.87               0.88     0.88      0.87
# AdaBoostClassifier                 0.86               0.87     0.87      0.86
# ExtraTreesClassifier               0.86               0.86     0.86      0.86
# CalibratedClassifierCV             0.86               0.86     0.86      0.86
# NuSVC                              0.85               0.86     0.86      0.85
# LinearSVC                          0.85               0.86     0.86      0.85
# LogisticRegression                 0.85               0.85     0.85      0.85
# RidgeClassifier                    0.84               0.85     0.85      0.84
# LinearDiscriminantAnalysis         0.84               0.85     0.85      0.84
# RidgeClassifierCV                  0.84               0.85     0.85      0.84
# SVC                                0.84               0.84     0.84      0.84
# SGDClassifier                      0.84               0.84     0.84      0.84
# DecisionTreeClassifier             0.84               0.84     0.84      0.84
# NearestCentroid                    0.82               0.82     0.82      0.82
# BernoulliNB                        0.80               0.81     0.81      0.80
# GaussianNB                         0.80               0.80     0.80      0.80
# KNeighborsClassifier               0.78               0.78     0.78      0.78
# ExtraTreeClassifier                0.78               0.78     0.78      0.78
# Perceptron                         0.76               0.76     0.76      0.76
# LabelPropagation                   0.74               0.75     0.75      0.74
# LabelSpreading                     0.74               0.75     0.75      0.74
# PassiveAggressiveClassifier        0.73               0.74     0.74      0.73
# QuadraticDiscriminantAnalysis      0.73               0.72     0.72      0.72
# DummyClassifier                    0.52               0.52     0.52      0.52
#
#                                Time Taken
# Model
# XGBClassifier                        0.05
# LGBMClassifier                       0.12
# RandomForestClassifier               0.20
# BaggingClassifier                    0.06
# AdaBoostClassifier                   0.13
# ExtraTreesClassifier                 0.12
# CalibratedClassifierCV               0.10
# NuSVC                                0.03
# LinearSVC                            0.03
# LogisticRegression                   0.02
# RidgeClassifier                      0.01
# LinearDiscriminantAnalysis           0.01
# RidgeClassifierCV                    0.01
# SVC                                  0.02
# SGDClassifier                        0.01
# DecisionTreeClassifier               0.02
# NearestCentroid                      0.01
# BernoulliNB                          0.01
# GaussianNB                           0.01
# KNeighborsClassifier                 0.02
# ExtraTreeClassifier                  0.01
# Perceptron                           0.01
# LabelPropagation                     0.04
# LabelSpreading                       0.04
# PassiveAggressiveClassifier          0.01
# QuadraticDiscriminantAnalysis        0.01
# DummyClassifier                      0.01
# 0.864
# [[105  10]
#  [ 24 111]]
#               precision    recall  f1-score   support
#
#          0.0     0.8140    0.9130    0.8607       115
#          1.0     0.9174    0.8222    0.8672       135
#
#     accuracy                         0.8640       250
#    macro avg     0.8657    0.8676    0.8639       250
# weighted avg     0.8698    0.8640    0.8642       250
